# %% [markdown]
# # Day 2 – Input & Operators in Python
# (Designed and instructed by Human GPT – Bhavesh)
#
# Welcome to Day 2 of your 15-Day Python learning journey!
# This material is created exclusively by Human GPT (Bhavesh).
#
# In this section, you will learn:
# - Taking input from users
# - Arithmetic operators
# - Comparison and assignment operators
# - Basic calculator program
#
# ---
#
# 📌 PART 2 — Instructions Section
#
# ## 📌 Instructions for Day 2
# 1. Complete Day 1 before starting Day 2.
# 2. Read all theory and execute each example.
# 3. Practice Level-1, Level-2, Level-3 questions in order.
# 4. Attempt all 10 challenge questions after finishing exercises.
# 5. Maintain a separate file named `Day2.py` or notebook `Day 2.ipynb`.
# 6. Revise both Day-1 and Day-2 topics for 10 minutes.
# 7. After completing, upload your file to Google Colab and click on Share then add my email:
#    studentpmc35@gmail.com
# 8. All the Best! Keep consistency alive!
#
# ---
#
# 📌 PART 3 — Theory + Example Codes
#
# ## 🧠 Day 2 – Theory
#
# ### Taking Input
# We use the input() function to take data from the user.
#
# Example:
# ```python
#
# name = input("Enter your name: ")
# print("Hello", name)
# ```
#
# ### Arithmetic Operators (Shown as RAW text)
# | Operator | Meaning              | Example |
# |---------|----------------------|---------|
# | +       | Addition             | a + b   |
# | -       | Subtraction          | a - b   |
# | *       | Multiplication       | a * b   |
# | /       | Division             | a / b   |
# | %       | Modulus (remainder)  | a % b   |
# | //      | Floor Division       | a // b  |
# | **      | Power                | a ** b  |
#
#
#
# ### Basic Mini Calculator Example
# ```python
#
# a = int(input("Enter first number: "))
#
# b = int(input("Enter second number: "))
#
# print("Sum =", a + b)
#
# print("Difference =", a - b)
#
# print("Product =", a * b)
#
# print("Division =", a / b)
# ```

# %% [markdown]
# ### 📌 Level 1 – Easy (5 Questions)
# 1. Take your name as input and print: "Welcome <name>"
# 2. Ask user age → print: "You are ___ years old"
# 3. Input city → print "You are from <city>"
# 4. Input any number → print the same number
# 5. Input two numbers → print their addition
#
# ---

# %% [markdown]
# ### 📌 Level 2 – Medium (5 Questions)
# 6. Take two numbers → print subtraction result
# 7. Input two numbers → multiply and show result
# 8. Ask 3 subject marks → print total marks
# 9. Input product price and quantity → print total bill
# 10. Input any number → print square of that number
#
# ---

# %% [markdown]
# ### 📌 Level 3 – Advanced (5 Questions)
# 11. Create a calculator: Take two numbers → print +, −, ×, ÷ results
# 12. Input first name + last name → print full name using f-string
# 13. Take two numbers → print floor division and modulus
# 14. Input number → print cube using power operator (**)
# 15. Ask the price → print properly formatted output like:
#     Price: ₹___
#
# ---

# %% [markdown]
# ---
#
# ### 📌 Level 3 – Advanced (5 Questions)
# 11. Create a calculator: Take two numbers → print +, −, ×, ÷ results
# 12. Input first name + last name → print full name using f-string
# 13. Take two numbers → print floor division and modulus
# 14. Input number → print cube using power operator (**)
# 15. Ask the price → print properly formatted output like:
#     Price: ₹___
#
# ---

# %% [markdown]
# ## 🔥 Challenge Problems (10 Questions)
#
# 16. Take two numbers → print the average (formatted).
# 17. Input birth year → calculate and display age.
# 18. Input length & width → print area of rectangle.
# 19. Ask marks out of 100 → print percentage.
# 20. Input 3 numbers → print total + average in a formatted line.
# 21. Input item name, price, qty → print bill in clean format.
# 22. Convert hours to minutes → print result.
# 23. Convert minutes to seconds → print result.
# 24. Take distance in km → convert to meters.
# 25. Ask student name, course, roll number → print Student ID card format.
#
# ---
#
# ### 📌 Submission Instruction
# ✓ Save as: `Day 2.py` or **Day 2.ipynb**
# ✓ Upload to Google Colab → Click **Share** → Add email below
# 📧 studentpmc35@gmail.com
#
# Complete minimum **15 questions** for Day-2 clearance!
