# %% [markdown]
# # Day 1 – Python Basics
# (Designed and instructed by Human GPT – Bhavesh)
#
# Welcome to Day 1 of your 15-day Python learning journey!
# This material is created exclusively by Human GPT (Bhavesh).
# No AI content — purely human-written learning guidance.
#
# In this section, you will learn:
# - What Python is and why it is used
# - Variables and basic data types
# - Printing and taking input from the user
# - Basic syntax and formatting rules in Python
#
# Follow the instructions step-by-step and practice every question.
#
# ---
#
# ## 📌 Instructions for Day 1
# 1. Read all theory and example programs first.
# 2. Type every program manually — do not copy-paste.
# 3. Practice Level-1, Level-2, Level-3 in order.
# 4. Attempt all 10 challenge questions for confidence.
# 5. Maintain a separate notes and code file for Day-1.
# 6. Revise for 10 minutes after completing the exercises.
# 7. Download this File and upload in your Google collab after completing it,click on Share and add my email 'studentpmc35@gmail.com'.
# All the Best!

# %% [markdown]
# # Day 1 – Basics of Python
#
# ## Part 1: Introduction to Python
# Python is a high-level, simple, and beginner-friendly programming language.
# It is used in:
# - AI & Machine Learning
# - Web Development
# - Game Development
# - Data Science & Automation
#
# ### Why Python?
# 1. Easy Syntax
# 2. Large Community Support
# 3. Supports multiple domains
#
# ---
#
# ## Part 2: Basic Syntax + Variables + Data Types (Theory)
# ### Basic Syntax Rules
# - Python code runs line by line (interpreted language)
# - Indentation is IMPORTANT (no curly braces)
# - Case Sensitive (age != Age)
#
# ### Variables
# Used to store data in memory.
# Example:
# x = 10
#
# ### Data Types
# | Type | Example |
# |------|---------|
# | Integer | 10 |
# | Float | 3.14 |
# | String | "Hello" |
# | Boolean | True / False |
#
# ---
#
# ## Part 3: Basic Example Codes
#
# ```python
# # Print Statement
# print("Welcome to Python!")
#
# # Variable Example
# name = "Bhavesh"
# age = 19
# print("Name:", name)
# print("Age:", age)
#
# # Datatype check
# print(type(age))

# %% [markdown]
# Practice the example from Above then go the the Practice Questions

# %% [markdown]
# # Day 1 – Python Practice Questions
# ## Level 1 (Easy) – 5 Questions
# ---
# 1. Print your full name.
# 2. Create variables: name, age, city → print each in separate lines.
# 3. Print the data type of variables: integer, float, string.
# 4. Store your college name and print: "I study at <college>" using concatenation.
# 5. Print two numbers in one print statement separated by space.
# ---

# %% [markdown]
# # Level 2 (Medium) – 5 Questions
# ---
# 6. Take user input: name, age → print: "My name is ___ and I am ___ years old".
# 7. Take two numbers as input → print their sum.
# 8. Input favorite movie + hometown → print formatted sentence.
# 9. Create variables for product and price → print using f-string.
# 10. Accept a string from user → print its data type.
#
# ---

# %% [markdown]
# ###input()-> string input from user
# ---
# ###int(input())-> Int input from user
# ---
# ###variable_name -f-string
# -print(f"The variable name is {variable_name}")

# %% [markdown]
# # Level 3 (Advanced Basics) – 5 Questions
# ---
# 11. Take first name + last name + age → print properly formatted output using f-string.
# 12. Take two numbers → print addition, subtraction, multiplication, division.
# 13. Print a paragraph using triple quotes.
# 14. Ask for 3 hobbies → show them in one sentence separated by commas.
# 15. Print formatted profile containing name, age, height & country in clean layout.
#
# ---

# %% [markdown]
# # Challenge Problems – 10 Questions (Beginner-Friendly)
# 16. Input total marks + maximum marks → calculate and print percentage.
# 17. Take a sentence → print length using len().
# 18. Input a number → print the number squared.
# 19. Take birth year → calculate and display current age.
# 20. Ask user for favorite food → print: "You love eating ___"
# 21. Input Celsius temperature → convert to Fahrenheit.
# 22. Take cost + quantity → print total price.
# 23. Print your name 3 times (can use 3 print statements).
# 24. Ask user for first name + last name → print initials like: A. K.
# 25. Input two numbers → print result of (A * B) in a formatted way.

# %% [markdown]
# ## Conclusion – Day 1 Completed 🎯
# Instructor: Human GPT (Bhavesh)
#
# ✓ You have completed Day 1
# ✓ You can now write basic Python programs
# ✓ You can use variables, data types, and input/output
#
# If you have completed at least:
# - 15 practice questions → You are Ready for Day-2
# - All 25 questions → Excellent Progress!
#
# Save your work and get ready for the next step in the journey!
